# %%
import json
json.loads("[\n  {\n    \"idiom\": \"(Are you) doing okay?\",\n    \"entities\": [],\n    \"literal_meanings\": [\n      \"How are you?\",\n      \"How are you surviving this situation or ordeal?\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are you) feeling okay?\",\n    \"entities\": [],\n    \"literal_meanings\": [\n      \"Do you feel well?\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are you) going my way?\",\n    \"entities\": [\n      \"way\"\n    ],\n    \"literal_meanings\": [\n      \"If you are traveling in the direction of my destination, could I please go with you or can I have a ride in your car?\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are you) leaving so soon?\",\n    \"entities\": [],\n    \"literal_meanings\": [\n      \"a polite inquiry made to a guest who has announced a departure. (Appropriate only for the first few guests to leave. It would seem sarcastic to say this to the last guest to leave or one who is leaving very late at night.)\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are you) ready for this?\",\n    \"entities\": [],\n    \"literal_meanings\": [],\n    \"figurative_meanings\": [\n      \"a way of presenting a piece of news or information that is expected to excite or surprise the person spoken to.\"\n    ]\n  },\n  {\n    \"idiom\": \"(Are you) ready to order?\",\n    \"entities\": [\n      \"order\"\n    ],\n    \"literal_meanings\": [\n      \"Would you please tell me what you want as your meal? (A standard phrase used in eating establishments to find out what a customer wants to eat.)\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are you) sorry you asked?\",\n    \"entities\": [],\n    \"literal_meanings\": [\n      \"Now that you have heard (the unpleasant answer), do you regret having asked the question? (Compare this with You’ll be sorry you asked.)\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Are) things getting you down?\",\n    \"entities\": [\n      \"thing\"\n    ],\n    \"literal_meanings\": [\n      \"Are everyday issues bothering you?\"\n    ],\n    \"figurative_meanings\": []\n  },\n  {\n    \"idiom\": \"(Aw) shucks!\",\n    \"entities\": [],\n    \"literal_meanings\": [],\n    \"figurative_meanings\": [\n      \"Rur. Gosh!; a mild oath.\"\n    ]\n  },\n  {\n    \"idiom\": \"(Could I) buy you a drink?\",\n    \"entities\": [\n      \"drink\"\n    ],\n    \"literal_meanings\": [\n      \"Could I purchase a drink for you? (An offer by one person—usually in a bar—to buy a drink for another. Then the two will drink together. Also used with can or may in place of could.)\"\n    ],\n    \"figurative_meanings\": [\n      \"Could I make you a drink? (A slightly humorous way of offering to prepare and serve someone a drink, as in one’s home. Also used with can or may in place of could.)\"\n    ]\n  }\n]")
# Out:
# [{'idiom': '(Are you) doing okay?',
#   'entities': [],
#   'literal_meanings': ['How are you?',
#    'How are you surviving this situation or ordeal?'],
#   'figurative_meanings': []},
#  {'idiom': '(Are you) feeling okay?',
#   'entities': [],
#   'literal_meanings': ['Do you feel well?'],
#   'figurative_meanings': []},
#  {'idiom': '(Are you) going my way?',
#   'entities': ['way'],
#   'literal_meanings': ['If you are traveling in the direction of my destination, could I please go with you or can I have a ride in your car?'],
#   'figurative_meanings': []},
#  {'idiom': '(Are you) leaving so soon?',
#   'entities': [],
#   'literal_meanings': ['a polite inquiry made to a guest who has announced a departure. (Appropriate only for the first few guests to leave. It would seem sarcastic to say this to the last guest to leave or one who is leaving very late at night.)'],
#   'figurative_meanings': []},
#  {'idiom': '(Are you) ready for this?',
#   'entities': [],
# ...
