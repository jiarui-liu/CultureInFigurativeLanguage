# %%
import pandas as pd
import json

df = pd.read_csv("/home/jiaruil5/culture_pretrain/CultureInFigurativeLanguage/culture/data/idiom_patterns.tsv", sep="\t", header=None)

# parse the JSON string in column 2
df
# Out:
#                          0                                                  1
# 0                    idiom                                           patterns
# 1           american dream  [[{"LEMMA": {"REGEX": "(?i)^american$"}}, {"TE...
# 2                 catch-22  [[{"LEMMA": {"REGEX": "(?i)^catch$"}}, {"TEXT"...
# 3        christmas present  [[{"LEMMA": {"REGEX": "(?i)^christmas$"}}, {"T...
# 4           downing street  [[{"LEMMA": {"REGEX": "(?i)^down$"}}, {"TEXT":...
# ...                    ...                                                ...
# 2752        younger sister  [[{"LEMMA": {"REGEX": "(?i)^young$"}}, {"TEXT"...
# 2753            zero in on  [[{"LEMMA": {"REGEX": "(?i)^zero$"}}, {"TEXT":...
# 2754              zero-day  [[{"LEMMA": {"REGEX": "(?i)^zero$"}}, {"TEXT":...
# 2755    come down to earth  [[{"LEMMA": {"REGEX": "(?i)^come$"}}, {"TEXT":...
# 2756  beat around the bush  [[{"LEMMA": {"REGEX": "(?i)^beat$"}}, {"TEXT":...
#
# [2757 rows x 2 columns]
