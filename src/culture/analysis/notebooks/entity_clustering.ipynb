# %%
# %load_ext autoreload
# %autoreload 2

# %%
from culture.analysis.entity_clustering import load_entities_from_file, plot_entity_distribution

idioms_zh_file = "/home/jiaruil5/culture_pretrain/CultureInFigurativeLanguage/culture/data/idioms/zh/idioms_merged_llm_formatted.jsonl"
idioms_en_file = "/home/jiaruil5/culture_pretrain/CultureInFigurativeLanguage/culture/data/idioms/en/idioms_merged_llm_formatted.jsonl"

# Load entities from both files
entity_counters = {
    "zh": load_entities_from_file(idioms_zh_file),
    "en": load_entities_from_file(idioms_en_file)
}
# Out:
# Bad value in file '/home/jiaruil5/.config/matplotlib/matplotlibrc', line 18 ("axes.prop_cycle : cycler(color=['#FFAF00','#F46920','#F53255','#F857C1','#29BDFD','#00CBBF','#01C159','#9DCA1C']) #hex colours"): Key axes.prop_cycle: "cycler(color=['" is not a valid cycler construction: unterminated string literal (detected at line 1) (<unknown>, line 1)
# {'idiom': '官卑职小', 'index': 9385, 'output': None}
# {'idiom': '流水不腐，户枢不蠹', 'index': 18095, 'output': None}
# {'idiom': '(I’ve) been getting by.', 'index': 200, 'output': None}
# {'idiom': 'bail someone or something out†', 'index': 3073, 'output': None}
# {'idiom': 'beam someone or something up† (to some place)', 'index': 3318, 'output': None}
# {'idiom': 'flatten someone or something out†', 'index': 10259, 'output': None}
# {'idiom': 'freshen someone or something up†', 'index': 10778, 'output': None}
# {'idiom': 'Here you go.', 'index': 13681, 'output': None}
# {'idiom': 'No way!', 'index': 19160, 'output': None}
# {'idiom': 'stick one’s nose in(to something)', 'index': 26662, 'output': None}
# {'idiom': 'What the deuce?', 'index': 30942, 'output': None}

# %%
# Plot entity distribution for Chinese idioms
plot_entity_distribution(entity_counters["zh"], top_k=30, src_lang="zh")
# Out:
# Translating entities to English...
# Using font: LXGW WenKai (from /home/jiaruil5/culture_pretrain/CultureInFigurativeLanguage/culture/data/fonts/LxgwWenKai-Regular.ttf)

# %%
# Plot entity distribution for Chinese idioms
plot_entity_distribution(entity_counters["en"], top_k=30, src_lang="en")
# Out:
# Using font: LXGW WenKai (from /home/jiaruil5/culture_pretrain/CultureInFigurativeLanguage/culture/data/fonts/LxgwWenKai-Regular.ttf)
